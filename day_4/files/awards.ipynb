# %%
import pandas as pd

import matplotlib.pyplot as plt

menu =  pd.read_csv(r'Z:\SEM-3\ML\day_4\files\indian_food.csv')

menu
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
name_and_time = menu[['name','prep_time','cook_time']].head(10)

name_and_time
# Out:
#              name  prep_time  cook_time
# 0      Balu shahi         45         25
# 1          Boondi         80         30
# 2  Gajar ka halwa         15         60
# 3          Ghevar         15         30
# 4     Gulab jamun         15         40
# 5          Imarti         10         50
# 6          Jalebi         10         50
# 7      Kaju katli         10         20
# 8        Kalakand         20         30
# 9           Kheer         10         40

# %%
name_and_time.plot(x='name',y=['prep_time','cook_time'])

ax = name_and_time.plot.area()

ax
# Out:
# <AxesSubplot:>

# %%
ax = name_and_time.plot.line(subplots=True)

ax
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
ax = name_and_time.plot.scatter(x='prep_time',y='cook_time')

ax
# Out:
# <AxesSubplot:xlabel='prep_time', ylabel='cook_time'>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv(r'Z:\SEM-3\ML\day_4\files\awards.csv')

# %%
df
# Out:
#     id  num_awards  prog  math
# 0   45         1.0   3.0  41.0
# 1  108         1.0   NaN   NaN
# 2   15         1.0   3.0  44.0
# 3   67         NaN   3.0  42.0
# 4  153         1.0   3.0  40.0
# 5   51         1.0   1.0   NaN
# 6  164         1.0   3.0  46.0
# 7  133         1.0   3.0  40.0
# 8    2         1.0   NaN  33.0
# 9   53         1.0   3.0  46.0

# %%
df['profit'] = np.where(df['id']<100,True,False)

# %%
df
# Out:
#     id  num_awards  prog  math  profit
# 0   45         1.0   3.0  41.0    True
# 1  108         1.0   NaN   NaN   False
# 2   15         1.0   3.0  44.0    True
# 3   67         NaN   3.0  42.0    True
# 4  153         1.0   3.0  40.0   False
# 5   51         1.0   1.0   NaN    True
# 6  164         1.0   3.0  46.0   False
# 7  133         1.0   3.0  40.0   False
# 8    2         1.0   NaN  33.0    True
# 9   53         1.0   3.0  46.0    True

# %%
values = {"id":0,"num_awards":1,"prog":2,"math":4}

# %%
df.fillna(values)
# Out:
#     id  num_awards  prog  math  profit
# 0   45         1.0   3.0  41.0    True
# 1  108         1.0   2.0   4.0   False
# 2   15         1.0   3.0  44.0    True
# 3   67         1.0   3.0  42.0    True
# 4  153         1.0   3.0  40.0   False
# 5   51         1.0   1.0   4.0    True
# 6  164         1.0   3.0  46.0   False
# 7  133         1.0   3.0  40.0   False
# 8    2         1.0   2.0  33.0    True
# 9   53         1.0   3.0  46.0    True
