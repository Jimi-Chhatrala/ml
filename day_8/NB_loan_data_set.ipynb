# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from scipy.stats import chi2_contingency
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB

df = pd.read_csv(r'Z:\SEM-3\ML\day_8\NB_loan_data_set.csv')
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No         0.0      Graduate            No             1.0
# 1      Male     Yes         1.0      Graduate            No             1.0
# 2      Male     Yes         0.0      Graduate           Yes             1.0
# 3      Male     Yes         0.0  Not Graduate            No             1.0
# 4      Male      No         0.0      Graduate            No             1.0
# ..      ...     ...         ...           ...           ...             ...
# 277    Male     Yes         0.0      Graduate            No             1.0
# 278    Male     Yes         0.0      Graduate            No             1.0
# 279  Female     Yes         0.0  Not Graduate            No             NaN
# 280    Male      No         1.0  Not Graduate           Yes             0.0
# 281    Male     Yes         0.0      Graduate            No             1.0
#
#     Property_Area  Loan_Status
# ...

# %%
numeric = LabelEncoder()

# %%
inputs = df.drop("Loan_Status",axis="columns")

# %%
target = df['Loan_Status']

# %%
inputs
# Out:
#      Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No         0.0      Graduate            No             1.0
# 1      Male     Yes         1.0      Graduate            No             1.0
# 2      Male     Yes         0.0      Graduate           Yes             1.0
# 3      Male     Yes         0.0  Not Graduate            No             1.0
# 4      Male      No         0.0      Graduate            No             1.0
# ..      ...     ...         ...           ...           ...             ...
# 277    Male     Yes         0.0      Graduate            No             1.0
# 278    Male     Yes         0.0      Graduate            No             1.0
# 279  Female     Yes         0.0  Not Graduate            No             NaN
# 280    Male      No         1.0  Not Graduate           Yes             0.0
# 281    Male     Yes         0.0      Graduate            No             1.0
#
#     Property_Area
# 0           Urban
# ...

# %%
df['Credit_History_n'] = numeric.fit_transform(df['Credit_History'])

# %%
target
# Out:
# 0         Approved
# 1      NotApproved
# 2         Approved
# 3         Approved
# 4         Approved
#           ...
# 277       Approved
# 278       Approved
# 279       Approved
# 280    NotApproved
# 281       Approved
# Name: Loan_Status, Length: 282, dtype: object

# %%
df['Gender_n'] = numeric.fit_transform(df['Gender'])
df['Married_n'] = numeric.fit_transform(df['Married'])
df['Dependents_n'] = numeric.fit_transform(df['Dependents'])
df['Education_n'] = numeric.fit_transform(df['Education'])
df['Self_Employed_n'] = numeric.fit_transform(df['Self_Employed'])

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 0      Male      No         0.0      Graduate            No             1.0
# 1      Male     Yes         1.0      Graduate            No             1.0
# 2      Male     Yes         0.0      Graduate           Yes             1.0
# 3      Male     Yes         0.0  Not Graduate            No             1.0
# 4      Male      No         0.0      Graduate            No             1.0
# ..      ...     ...         ...           ...           ...             ...
# 277    Male     Yes         0.0      Graduate            No             1.0
# 278    Male     Yes         0.0      Graduate            No             1.0
# 279  Female     Yes         0.0  Not Graduate            No             NaN
# 280    Male      No         1.0  Not Graduate           Yes             0.0
# 281    Male     Yes         0.0      Graduate            No             1.0
#
# ...
