# %%
import pandas as pd

df = pd.read_csv(r'Z:\SEM-3\ML\student_scores.csv')

df
# Out:
#     Hours  Scores  Pass
# 0     2.3      18     0
# 1     5.0      45     1
# 2     3.2      25     0
# 3     8.5      72     1
# 4     3.5      30     0
# 5     1.5      20     0
# 6     9.2      88     1
# 7     5.5      60     1
# 8     8.3      81     1
# 9     2.7      25     0
# 10    7.7      85     1
# 11    5.9      62     1
# 12    4.5      41     1
# 13    3.4      44     1
# 14    1.1      17     0
# 15    8.9      95     1
# 16    2.5      30     0
# 17    1.9      24     0
# 18    6.1      67     1
# 19    7.4      69     1
# 20    2.7      30     0
# 21    4.8      54     1
# 22    3.7      33     0
# 23    6.8      70     1
# 24    7.4      85     1

# %%
df.head()
# Out:
#    Hours  Scores  Pass
# 0    2.3      18     0
# 1    5.0      45     1
# 2    3.2      25     0
# 3    8.5      72     1
# 4    3.5      30     0

# %%
df.columns = df.columns.str.upper()

# %%
df
# Out:
#     HOURS  SCORES  PASS
# 0     2.3      18     0
# 1     5.0      45     1
# 2     3.2      25     0
# 3     8.5      72     1
# 4     3.5      30     0
# 5     1.5      20     0
# 6     9.2      88     1
# 7     5.5      60     1
# 8     8.3      81     1
# 9     2.7      25     0
# 10    7.7      85     1
# 11    5.9      62     1
# 12    4.5      41     1
# 13    3.4      44     1
# 14    1.1      17     0
# 15    8.9      95     1
# 16    2.5      30     0
# 17    1.9      24     0
# 18    6.1      67     1
# 19    7.4      69     1
# 20    2.7      30     0
# 21    4.8      54     1
# 22    3.7      33     0
# 23    6.8      70     1
# 24    7.4      85     1

# %%
import pandas as pd

df = pd.read_csv(r'Z:\SEM-3\ML\indian_food.csv')

df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df.head(15)
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
import pandas as pd

df = pd.read_csv(r'Z:\SEM-3\ML\graph_data.csv')

df
# Out:
#    product  profit  loss
# 0       12      10    34
# 1       23      20    76
# 2       34      30    42
# 3       45      35    98
# 4       56      70    45
# 5       67      34    90

# %%
import pandas as pd

import matplotlib.pyplot as plt

get_ipython().run_line_magic('matplotlib','inline')

df.plot(x="product",y=['profit','loss'])
# Out:
# <AxesSubplot:xlabel='product'>

# %%
df = df.plot.area()

# %%
import pandas as pd

import matplotlib.pyplot as plt

get_ipython().run_line_magic('matplotlib','inline')

df = pd.read_csv(r'Z:\SEM-3\ML\graph_data.csv')

ax = df.plot.bar(x='product',y='loss')

# %%
ax = df.plot.bar(x='product',y='profit')

# %%
ax = df.plot.box()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
ax = df.plot.line()

# %%
ax = df.plot.line(subplots = True)

# %%
ax = df.plot.pie(y='profit',figsize=(7,7))

# %%
ax = df.plot.pie(y='loss',figsize=(7,7))

# %%
ax = df.plot.pie(subplots = True,figsize=(7,7))

# %%
df = pd.read_csv(r'Z:\SEM-3\ML\student_scores.csv')
df.head(5)
df.plot(x='Scores',y=['Pass'])
# Out:
# <AxesSubplot:xlabel='Scores'>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(x='Scores',y='Pass')
# Out:
# <AxesSubplot:xlabel='Scores'>

# %%
df.plot.box(x='Scores',y='Pass')
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df.plot.line(subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
df.plot.pie(y='Scores',figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='Scores'>

# %%
df.plot.pie(subplots=True,figsize=(7,7))
# Out:
# array([<AxesSubplot:ylabel='Hours'>, <AxesSubplot:ylabel='Scores'>,
#        <AxesSubplot:ylabel='Pass'>], dtype=object)

# %%
df = pd.read_csv(r'Z:\SEM-3\ML\test.csv')
# df = pd.read_csv(r'Z:\SEM-3\ML\test.csv',usecols=['Pclass','Sex','Age'])
df = df.dropna()[:20] 
df
# df.plot(x='Scores',y=['Pass'])
# Out:
#     PassengerId  Pclass                                               Name  \
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26          918       1                       Ostby, Miss. Helene Ragnhild
# 28          920       1                            Brady, Mr. John Bertram
# 34          926       1                           Mock, Mr. Philipp Edmund
# 44          936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46          938       1                           Chevre, Mr. Paul Romaine
# 48          940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 50          942       1                           Smith, Mr. Lucien Philip
# 53          945       1                         Fortune, Miss. Ethel Flora
# ...
